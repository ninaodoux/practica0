# %%
import pandas as pd
import numpy as np
import os as os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ninao\\Desktop\\practica\\practica0\\notebooks'

# %%
path ="../data/titanic1.csv"
titanic_df = pd.read_csv(path, sep=';', low_memory=False)
print(titanic_df)
# Out:
#                                                   Name  Pclass     Sex   Age  \
# 0                               Mr. Owen Harris Braund       3    male  22.0
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...       1  female  38.0
# 2                                Miss. Laina Heikkinen       3  female  26.0
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle       1  female  35.0
# 4                              Mr. William Henry Allen       3    male  35.0
# ..                                                 ...     ...     ...   ...
# 882                               Rev. Juozas Montvila       2    male  27.0
# 883                        Miss. Margaret Edith Graham       1  female  19.0
# 884                     Miss. Catherine Helen Johnston       3  female   7.0
# 885                               Mr. Karl Howell Behr       1    male  26.0
# 886                                 Mr. Patrick Dooley       3    male  32.0
#
# ...

# %%
#Explorar el dataset con màs info

print(titanic_df.head())
print(titanic_df.info())
# Out:
#                                                 Name  Pclass     Sex   Age  \
# 0                             Mr. Owen Harris Braund       3    male  22.0
# 1  Mrs. John Bradley (Florence Briggs Thayer) Cum...       1  female  38.0
# 2                              Miss. Laina Heikkinen       3  female  26.0
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle       1  female  35.0
# 4                            Mr. William Henry Allen       3    male  35.0
#
#    Siblings/Spouses Aboard  Parents/Children Aboard     Fare  Survived
# 0                        1                        0   7.2500         0
# 1                        1                        0  71.2833         1
# 2                        0                        0   7.9250         1
# 3                        1                        0  53.1000         1
# 4                        0                        0   8.0500         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# ...

# %%
#tenemos 887 obs y 8 variables
#Ahora importamos librerias 

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report,ConfusionMatrixDisplay
from sklearn import tree

# %%
import matplotlib.pyplot as mplt

# %%
#para ver las columnas 
print(titanic_df.columns)
# Out:
# Index(['Name', 'Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard',
#        'Parents/Children Aboard', 'Fare', 'Survived'],
#       dtype='object')

# %%
#preprocesar los datos :

#verificar el tipo con

print(titanic_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     887 non-null    object
#  1   Pclass                   887 non-null    int64
#  2   Sex                      887 non-null    object
#  3   Age                      887 non-null    float64
#  4   Siblings/Spouses Aboard  887 non-null    int64
#  5   Parents/Children Aboard  887 non-null    int64
#  6   Fare                     887 non-null    float64
#  7   Survived                 887 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB
# None

# %%
#convertimos las numericas

titanic_df['Sex'] = titanic_df['Sex'].map({'male':0, 'female':1})

#llenar los valores faltantes NaN cuando hay 
titanic_df.isna().sum()

#no hace falta
# Out:
# Name                       0
# Pclass                     0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# Survived                   0
# dtype: int64

# %%
#separar variables independientes y dependientes 
#variables independientes 

x= titanic_df[['Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare']]

#las dependientes: porque establecemos que vivir o sobrevivir depende de las variables x

y= titanic_df['Survived']

# %%
#Dividir los datos en TRAIN y TEST 

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
#construccion del arbol de classification 

#arbol de decision 
clf = DecisionTreeClassifier()

#Entrenar el classif

clf.fit(x_train, y_train)

#predecir en el cojunto de TEST

y_pred= clf.predict(x_test)

# %%
#evaluar el rendimiento del modelo 

from sklearn import metrics

print("Accuracy:", metrics.accuracy_score(y_test,y_pred))
print("Confusion Matrix:\n", metrics.classification_report(y_test,y_pred))
print("Classification report:\n", metrics.classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.7471910112359551
# Confusion Matrix:
#                precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79       111
#            1       0.65      0.72      0.68        67
#
#     accuracy                           0.75       178
#    macro avg       0.73      0.74      0.74       178
# weighted avg       0.75      0.75      0.75       178
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79       111
#            1       0.65      0.72      0.68        67
#
#     accuracy                           0.75       178
#    macro avg       0.73      0.74      0.74       178
# weighted avg       0.75      0.75      0.75       178

# %%
#visualizacion del arbol 

import matplotlib.pyplot as mplt 
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))
plot_tree(clf, feature_names=['Pclass', 'Sex', 'Age', 'Siblings/Spouses Aboard', 'Parents/Children Aboard', 'Fare'], class_names=['Not Survived', 'Survived'])
plt.show()
